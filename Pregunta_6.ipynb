# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
from src import gauss_jacobi, gauss_seidel
# Out:
# [02-12 15:23:57][INFO][Alex] 2026-02-12 15:23:57.095172
# [02-12 15:23:57][INFO][Alex] 2026-02-12 15:23:57.096168
# [02-12 15:23:57][INFO][Alex] 2026-02-12 15:23:57.097182

# %%
def trayectoria_gs(A, b, x0, tol=1e-6, it=10):
    # Inicializamos la trayectoria con el punto inicial
    tray = [x0.copy().reshape(-1, 1)]
    x_actual = x0.copy()
    
    for k in range(it):
        # NOTA: Cambiamos 'x0' por 'x' para que coincida con tu librería
        x_actual = gauss_seidel(A=A, b=b, x=x_actual, tol=tol, max_iter=1)
        tray.append(x_actual)
        
    return np.hstack(tray).T

# %%
def dibujar(tray, titulo):
    x = tray[:,0]
    y = tray[:,1]

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, "o-", color="blue", alpha=0.6) # Línea con puntos
    plt.plot(x[0], y[0], "gd", markersize=10, label="X0 (Inicio)")
    plt.plot(x[-1], y[-1], "ro", markersize=10, label="X* (Final)")
    plt.xlabel("Eje X")
    plt.ylabel("Eje Y")
    plt.title(titulo)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# # Ejercicio 1

# %%
A1 = np.array([[2, 3], [1, 2]], float)
b1 = np.array([5, 8], float)
x0_1 = np.array([0, 0], float)

tray1 = trayectoria_gs(A1, b1, x0_1)
dibujar(tray1, "Primer Ejercicio: Trayectoria Gauss-Seidel")

sol1 = tray1[-1]
# Pendiente m = (y2-y1)/(x2-x1)
m1 = (tray1[-1, 1] - tray1[0, 1]) / (tray1[-1, 0] - tray1[0, 0])

print(f"--- Ejercicio 1 ---")
print("Respuesta (Solución):", sol1)
print("Pendiente m =", m1)
# Out:
# [02-12 15:29:47][INFO][Alex] i= 0 x: [0. 0.]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[2.5  2.75]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[2.5  2.75]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-1.625   4.8125]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-1.625   4.8125]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-4.71875   6.359375]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-4.71875   6.359375]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-7.0390625   7.51953125]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-7.0390625   7.51953125]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-8.77929688  8.38964844]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-8.77929688  8.38964844]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-10.08447266   9.04223633]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-10.08447266   9.04223633]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-11.06335449   9.53167725]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-11.06335449   9.53167725]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-11.79751587   9.89875793]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-11.79751587   9.89875793]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-12.3481369   10.17406845]]
# [02-12 15:29:47][INFO][Alex] i= 0 x: [[-12.3481369   10.17406845]]
# [02-12 15:29:47][INFO][Alex] i= 1 x: [[-12.76110268  10.38055134]]
# --- Ejercicio 1 ---
# Respuesta (Solución): [-12.76110268  10.38055134]
# Pendiente m = -0.8134525363078625

# %% [markdown]
# # Ejercicio 2

# %%
A2 = np.array([[1, 1], [-2, 1]], float)
b2 = np.array([6, 0], float)
x0_2 = np.array([0, 0], float)

tray2 = trayectoria_gs(A2, b2, x0_2)
dibujar(tray2, "Ejercicio 2: Trayectoria Gauss-Seidel")

sol2 = tray2[-1]
m2 = (tray2[-1, 1] - tray2[0, 1]) / (tray2[-1, 0] - tray2[0, 0])

print(f"\n--- Ejercicio 2 ---")
print("Solución:", sol2)
print("Pendiente m =", m2)
# Out:
# [02-12 15:30:04][INFO][Alex] i= 0 x: [0. 0.]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[ 6. 12.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[ 6. 12.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[ -6. -12.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[ -6. -12.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[18. 36.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[18. 36.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[-30. -60.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[-30. -60.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[ 66. 132.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[ 66. 132.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[-126. -252.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[-126. -252.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[258. 516.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[258. 516.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[ -510. -1020.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[ -510. -1020.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[1026. 2052.]]
# [02-12 15:30:04][INFO][Alex] i= 0 x: [[1026. 2052.]]
# [02-12 15:30:04][INFO][Alex] i= 1 x: [[-2046. -4092.]]
# --- Ejercicio 2 ---
# Solución: [-2046. -4092.]
# Pendiente m = 2.0
